# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('C:/Users/ajs/Desktop/example/python/DataAnalytics/d.csv')

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %% [markdown]
# # head is for finding heading of file that return 5 row details

# %%
df.head()
# Out:
#                  Student          ID  SIS User ID               SIS Login ID  \
# 0        Points Possible         NaN          NaN                        NaN
# 1                    NaN  27235077.0          NaN   ritikgupta0912@gmail.com
# 2  101690608197494578607  27236345.0          NaN      101690608197494578607
# 3                  aadya  27235394.0          NaN  mahimagupta8462@gmail.com
# 4        Agrawal, Muskan  27236194.0          NaN      agrawalm883@gmail.com
#
#              Root Account Section  test (16423460) Assignments Current Points  \
# 0                     NaN     NaN              2.0                (read only)
# 1  canvas.instructure.com      si              1.0                       1.00
# 2  canvas.instructure.com      si              NaN                       0.00
# 3  canvas.instructure.com      si              NaN                       0.00
# 4  canvas.instructure.com      si              1.0                       1.00
#
# ...

# %%
df.shape
# Out:
# (13, 19)

# %%
df.columns
# Out:
# Index(['Student', 'ID', 'SIS User ID', 'SIS Login ID', 'Root Account',
#        'Section', 'test (16423460)', 'Assignments Current Points',
#        'Assignments Final Points', 'Assignments Current Score',
#        'Assignments Unposted Current Score', 'Assignments Final Score',
#        'Assignments Unposted Final Score', 'Current Points', 'Final Points',
#        'Current Score', 'Unposted Current Score', 'Final Score',
#        'Unposted Final Score'],
#       dtype='object')

# %% [markdown]
# # for find the data type of row

# %%
df.dtypes
# Out:
# Student                                object
# ID                                    float64
# SIS User ID                           float64
# SIS Login ID                           object
# Root Account                           object
# Section                                object
# test (16423460)                       float64
# Assignments Current Points             object
# Assignments Final Points               object
# Assignments Current Score              object
# Assignments Unposted Current Score     object
# Assignments Final Score                object
# Assignments Unposted Final Score       object
# Current Points                         object
# Final Points                           object
# Current Score                          object
# Unposted Current Score                 object
# Final Score                            object
# Unposted Final Score                   object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 19 columns):
# Student                               12 non-null object
# ID                                    12 non-null float64
# SIS User ID                           0 non-null float64
# SIS Login ID                          7 non-null object
# Root Account                          7 non-null object
# Section                               12 non-null object
# test (16423460)                       4 non-null float64
# Assignments Current Points            13 non-null object
# Assignments Final Points              13 non-null object
# Assignments Current Score             4 non-null object
# Assignments Unposted Current Score    4 non-null object
# Assignments Final Score               13 non-null object
# Assignments Unposted Final Score      13 non-null object
# Current Points                        13 non-null object
# Final Points                          13 non-null object
# ...

# %%
section=df['Section']
section
# Out:
# 0     NaN
# 1      si
# 2      si
# 3      si
# 4      si
# 5      si
# 6      si
# 7      si
# 8      si
# 9      si
# 10     si
# 11     si
# 12     si
# Name: Section, dtype: object

# %%
section.head()
# Out:
# 0    NaN
# 1     si
# 2     si
# 3     si
# 4     si
# Name: Section, dtype: object

# %%
section.tail()
# Out:
# 8     si
# 9     si
# 10    si
# 11    si
# 12    si
# Name: Section, dtype: object

# %%
subset = df[['Section','ID']]
subset
# Out:
#    Section          ID
# 0      NaN         NaN
# 1       si  27235077.0
# 2       si  27236345.0
# 3       si  27235394.0
# 4       si  27236194.0
# 5       si  27236023.0
# 6       si  27235182.0
# 7       si  27236191.0
# 8       si  27242890.0
# 9       si  27236207.0
# 10      si  27241458.0
# 11      si  27235860.0
# 12      si  27241493.0

# %% [markdown]
# for finding row detail

# %%
first=df.loc[0]
first
# Out:
# Student                                   Points Possible
# ID                                                    NaN
# SIS User ID                                           NaN
# SIS Login ID                                          NaN
# Root Account                                          NaN
# Section                                               NaN
# test (16423460)                                         2
# Assignments Current Points                    (read only)
# Assignments Final Points                      (read only)
# Assignments Current Score                     (read only)
# Assignments Unposted Current Score            (read only)
# Assignments Final Score                       (read only)
# Assignments Unposted Final Score              (read only)
# Current Points                                (read only)
# Final Points                                  (read only)
# Current Score                                 (read only)
# ...

# %%
df.tail(n=1)
# Out:
#     Student          ID  SIS User ID SIS Login ID Root Account Section  \
# 12  utkarsh  27241493.0          NaN          NaN          NaN      si
#
#     test (16423460) Assignments Current Points Assignments Final Points  \
# 12              NaN                       0.00                     0.00
#
#    Assignments Current Score Assignments Unposted Current Score  \
# 12                       NaN                                NaN
#
#    Assignments Final Score Assignments Unposted Final Score Current Points  \
# 12                    0.00                             0.00           0.00
#
#    Final Points Current Score Unposted Current Score Final Score  \
# 12         0.00           NaN                    NaN        0.00
#
#    Unposted Final Score
# 12                 0.00

# %%
#df[-1]
#access multiple row
print(df.loc[[0,13,3]])
# Out:
#                 Student          ID  SIS User ID               SIS Login ID  \
# 0       Points Possible         NaN          NaN                        NaN
# 13                  NaN         NaN          NaN                        NaN
# 3                 aadya  27235394.0          NaN  mahimagupta8462@gmail.com
#
#               Root Account Section  test (16423460)  \
# 0                      NaN     NaN              2.0
# 13                     NaN     NaN              NaN
# 3   canvas.instructure.com      si              NaN
#
#    Assignments Current Points Assignments Final Points  \
# 0                 (read only)              (read only)
# 13                        NaN                      NaN
# 3                        0.00                     0.00
#
#    Assignments Current Score Assignments Unposted Current Score  \
# 0                (read only)                        (read only)
# 13                       NaN                                NaN
# ...

# %%
df.iloc[1]#iloc is same as loc only give to row no
#we can access last row by -1
df.iloc[-1]
# Out:
# Student                                   utkarsh
# ID                                    2.72415e+07
# SIS User ID                                   NaN
# SIS Login ID                                  NaN
# Root Account                                  NaN
# Section                                        si
# test (16423460)                               NaN
# Assignments Current Points                   0.00
# Assignments Final Points                     0.00
# Assignments Current Score                     NaN
# Assignments Unposted Current Score            NaN
# Assignments Final Score                      0.00
# Assignments Unposted Final Score             0.00
# Current Points                               0.00
# Final Points                                 0.00
# Current Score                                 NaN
# Unposted Current Score                        NaN
# Final Score                                  0.00
# Unposted Final Score                         0.00
# ...

# %%
#df.loc[-1]#we can't access last row by -1b

# %%
#we find 0,,2,3,row together

# %%
df.iloc[[0,2,3]]
# Out:
#                  Student          ID  SIS User ID               SIS Login ID  \
# 0        Points Possible         NaN          NaN                        NaN
# 2  101690608197494578607  27236345.0          NaN      101690608197494578607
# 3                  aadya  27235394.0          NaN  mahimagupta8462@gmail.com
#
#              Root Account Section  test (16423460) Assignments Current Points  \
# 0                     NaN     NaN              2.0                (read only)
# 2  canvas.instructure.com      si              NaN                       0.00
# 3  canvas.instructure.com      si              NaN                       0.00
#
#   Assignments Final Points Assignments Current Score  \
# 0              (read only)               (read only)
# 2                     0.00                       NaN
# 3                     0.00                       NaN
#
#   Assignments Unposted Current Score Assignments Final Score  \
# 0                        (read only)             (read only)
# ...

# %%
subset=df.loc[:2,['Section','ID']]
subset
# Out:
#   Section          ID
# 0     NaN         NaN
# 1      si  27235077.0
# 2      si  27236345.0

# %%
df.iloc[:,[1,3,5]]
# Out:
#             ID                 SIS Login ID Section
# 0          NaN                          NaN     NaN
# 1   27235077.0     ritikgupta0912@gmail.com      si
# 2   27236345.0        101690608197494578607      si
# 3   27235394.0    mahimagupta8462@gmail.com      si
# 4   27236194.0        agrawalm883@gmail.com      si
# 5   27236023.0                          NaN      si
# 6   27235182.0    Mahima1832022@akgec.ac.in      si
# 7   27236191.0   muskaanmittal129@gmail.com      si
# 8   27242890.0                          NaN      si
# 9   27236207.0  sachinkpprajapati@gmail.com      si
# 10  27241458.0                          NaN      si
# 11  27235860.0                          NaN      si
# 12  27241493.0                          NaN      si

# %%
small_range=list(range(4))
small_range
# Out:
# [0, 1, 2, 3]

# %%
df.iloc[:,small_range]
# Out:
#                   Student          ID  SIS User ID  \
# 0         Points Possible         NaN          NaN
# 1                     NaN  27235077.0          NaN
# 2   101690608197494578607  27236345.0          NaN
# 3                   aadya  27235394.0          NaN
# 4         Agrawal, Muskan  27236194.0          NaN
# 5                   arnav  27236023.0          NaN
# 6                  mahima  27235182.0          NaN
# 7         Mittal, Muskaan  27236191.0          NaN
# 8                 namrata  27242890.0          NaN
# 9       Prajapati, Sachin  27236207.0          NaN
# 10                tanishq  27241458.0          NaN
# 11                 tapish  27235860.0          NaN
# 12                utkarsh  27241493.0          NaN
#
#                    SIS Login ID
# 0                           NaN
# 1      ritikgupta0912@gmail.com
# 2         101690608197494578607
# 3     mahimagupta8462@gmail.com
# 4         agrawalm883@gmail.com
# 5                           NaN
# ...

# %% [markdown]
# subsetting row and columns together

# %%
df.loc[3,'Section']
# Out:
# 'si'

# %% [markdown]
# set multiple row and columns

# %%
df.iloc[[0,2,1],[1,4]]
# Out:
#            ID            Root Account
# 0         NaN                     NaN
# 2  27236345.0  canvas.instructure.com
# 1  27235077.0  canvas.instructure.com

# %% [markdown]
# note down use instead of row no using name for better understanding
# using loc instead of iloc

# %%
df.head(n=10)
# Out:
#                  Student          ID  SIS User ID  \
# 0        Points Possible         NaN          NaN
# 1                    NaN  27235077.0          NaN
# 2  101690608197494578607  27236345.0          NaN
# 3                  aadya  27235394.0          NaN
# 4        Agrawal, Muskan  27236194.0          NaN
# 5                  arnav  27236023.0          NaN
# 6                 mahima  27235182.0          NaN
# 7        Mittal, Muskaan  27236191.0          NaN
# 8                namrata  27242890.0          NaN
# 9      Prajapati, Sachin  27236207.0          NaN
#
#                   SIS Login ID            Root Account Section  \
# 0                          NaN                     NaN     NaN
# 1     ritikgupta0912@gmail.com  canvas.instructure.com      si
# 2        101690608197494578607  canvas.instructure.com      si
# 3    mahimagupta8462@gmail.com  canvas.instructure.com      si
# 4        agrawalm883@gmail.com  canvas.instructure.com      si
# ...

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
df.groupby(['year','continent'])['pop'].mean()
# Out:
# year  continent
# 1952  Africa       4.570010e+06
#       Americas     1.380610e+07
#       Asia         4.228356e+07
#       Europe       1.393736e+07
#       Oceania      5.343003e+06
# 1957  Africa       5.093033e+06
#       Americas     1.547816e+07
#       Asia         4.735699e+07
#       Europe       1.459635e+07
#       Oceania      5.970988e+06
# 1962  Africa       5.702247e+06
#       Americas     1.733081e+07
#       Asia         5.140476e+07
#       Europe       1.534517e+07
#       Oceania      6.641759e+06
# 1967  Africa       6.447875e+06
#       Americas     1.922986e+07
#       Asia         5.774736e+07
#       Europe       1.603930e+07
#       Oceania      7.300207e+06
# 1972  Africa       7.305376e+06
#       Americas     2.117537e+07
#       Asia         6.518098e+07
#       Europe       1.668784e+07
#       Oceania      8.053050e+06
# 1977  Africa       8.328097e+06
#       Americas     2.312271e+07
#       Asia         7.225799e+07
# ...

# %%
small=df.groupby(['year','continent'])['pop','gdpPercap'].mean()

# %%
small.shape
# Out:
# (60, 2)

# %% [markdown]
# you you need to flatten the data set use reset_index()

# %%
small.reset_index().head()
# Out:
#    year continent           pop     gdpPercap
# 0  1952    Africa  4.570010e+06   1252.572466
# 1  1952  Americas  1.380610e+07   4079.062552
# 2  1952      Asia  4.228356e+07   5195.484004
# 3  1952    Europe  1.393736e+07   5661.057435
# 4  1952   Oceania  5.343003e+06  10298.085650

# %% [markdown]
# grouped freq count

# %% [markdown]
# use the nunique to get count of unique value on pandas series

# %%
df.groupby('continent')['country'].nunique()
# Out:
# continent
# Africa      52
# Americas    25
# Asia        33
# Europe      30
# Oceania      2
# Name: country, dtype: int64

# %% [markdown]
# basic plot

# %%
global_yearly_life_expectancy=df.groupby('year')['lifeExp'].mean()
global_yearly_life_expectancy
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
global_yearly_life_expectancy.plot()
